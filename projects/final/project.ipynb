# %% [markdown]
# Богдан, рад приветствовать тебя)
#
# На связи твой тимлид Александр Дьяченко, думаю правила ты знаешь, но я повторю.
# Предлагаю общаться на "ты", если это для тебя приемлемо)
#
# В твоей работе я оставлю некоторые комментарии, которые помогут лучше понять материал или скажу, что все сделано верно.
# Давай договоримся об условных обозначениях, чтобы наше общение было эффективнее:
#
# Комментарии будут в <font color='green'>зеленой ✔️</font>, <font color='orange'>оранжевой ⚠️</font> или <font color='red'>красной ❌</font> рамках:
#
#
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# Зеленым цветом помечены образцовые решения. Которые можно использовать в дальнейшем.
#
# </div>
#
# <div class="alert alert-block alert-warning"; style="border-left: 6px solid orange">
# <b>Рекомендация ⚠️</b>
#
# Желтым цветом отмечено то, что ты можешь улучшить или доработать. Можешь учесть это при выполнении следующих работ или доработать проект сейчас, но это не обязательно.
#
# </div>
#
# <div class="alert alert-block alert-danger"; style="border-left: 6px solid red">
# <b>Ошибка ❌</b>
#
# Красным цветом помечены моменты, которые необходимо доработать, чтобы проект был принят. Уверен, что у тебя все получится. Буду ждать твою работу на повторное ревью.
#
# </div>
#
# -------------------
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b> Свои комментарии и вопросы ты можешь оставлять в синей рамочке. Также используй её, если что-то исправил, доделал или полностью переписал.</div>
#
#
#
#
# Старайся отвечать на мои рекомендации и не удалять комментарии, так получится проверить работу быстрее)
#
# Погнали!
#
#
#
# -------

# %% [markdown]
# Вопросы:
# - В презентации написано "Объединение датафреймов (исследование единого датафрейма)" - я правильно понимаю, что после объединения, начинается анализ данных? А потом работа с моделями.
# - Стоит ли убирать\добавлять столбцы при анализе? Если да, то какие столбцы стоит убрать\добавить и почему?
# - На что лучше акцентировать внимание при анализе в данном проекте?
# - Какие модели лучше всего использовать?
#
# Извиняюсь, если у меня глупые вопросы - буду рад советам :)

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# 1. Да, все так
# 2. Это решать тебе) Также это обсуджалось на созвоне
# 3. И это тоже ты решаешь сам. Я бы постарался понять в чем разница между теми кто ушел и остался
# 4. На этот вопрос тебе предстоит ответить самому, финальный проект подразумевает самостоятельное принятие решений) Если что-то будет неверно я сообщу при проверке
#
# </div>

# %% [markdown]
# # Телекоммуникации
# ## План и цель работы:
# ### План
# 1. Изучение заданий и требований к данному проекту.
# 2. Подготовка данных.
# 3. Анализ данных.
# 4. Обучение моделей.
# 5. Тестирование лучшей модели.
# 6. Отчет
#
# ### Цель
# При проверке качества лучшей модели на тестовой выборке надо получить 0.85 <= AUC-ROC

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# Не забываем в конце сделать анализ лучшей модели (важность признаков, матрица ошибок)
#
# </div>

# %% [markdown]
# ## Описание

# %% [markdown]
# ### Описание проекта
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# ### Описание услуг
# Оператор предоставляет два основных типа услуг:
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line, «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
#
# Также доступны такие услуги:
# - Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity);
# - Выделенная линия технической поддержки (TechSupport);
# - Облачное хранилище файлов для резервного копирования данных (OnlineBackup);
# - Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# ### Описание данных
# - contract_new.csv — информация о договоре;
# - personal_new.csv — персональные данные клиента;
# - internet_new.csv — информация об интернет-услугах;
# - phone_new.csv — информация об услугах телефонии.
#
# Во всех файлах столбец customerID содержит код клиента.
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# Хорошее введение
#
# </div>

# %% [markdown]
# ## Подгтовка

# %%
# !pip install phik

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import phik

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.compose import make_column_transformer

from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.pipeline import make_pipeline

from catboost import CatBoostClassifier

from lightgbm import LGBMClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import roc_auc_score, roc_curve

from sklearn.metrics import confusion_matrix

from sklearn.inspection import permutation_importance

import warnings
warnings.filterwarnings('ignore')

# %%
random_state = 30723

# %% [markdown]
# ### Загрузка данных

# %%
try:
    contract = pd.read_csv('/datasets/contract_new.csv')
    personal = pd.read_csv('/datasets/personal_new.csv')
    internet = pd.read_csv('/datasets/internet_new.csv')
    phone = pd.read_csv('/datasets/phone_new.csv')
except:
    contract = pd.read_csv('datasets/contract_new.csv')
    personal = pd.read_csv('datasets/personal_new.csv')
    internet = pd.read_csv('datasets/internet_new.csv')
    phone = pd.read_csv('datasets/phone_new.csv')

# %% [markdown]
# ### Просмотр данных

# %%
def information(dataframe):
    """
    вывод информации о dataframe
    """
    print('-' * 100)
    print('dataframe:')
    print('-' * 100)
    print(dataframe.head(10))
    print('-' * 100)
    print('info:')
    print('-' * 100)
    print(dataframe.info())
    print('-' * 100)
    print('describe:')
    print('-' * 100)
    print(dataframe.describe())
    print('-' * 100)

# %%
information(contract)
# Out:
# ----------------------------------------------------------------------------------------------------
# dataframe:
# ----------------------------------------------------------------------------------------------------
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01          No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01          No        One year               No
# 2  3668-QPYBK  2019-10-01          No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01          No        One year               No
# 4  9237-HQITU  2019-09-01          No  Month-to-month              Yes
# 5  9305-CDSKC  2019-03-01          No  Month-to-month              Yes
# 6  1452-KIOVK  2018-04-01          No  Month-to-month              Yes
# 7  6713-OKOMC  2019-04-01          No  Month-to-month               No
# 8  7892-POOKP  2017-07-01          No  Month-to-month              Yes
# ...

# %%
contract['TotalCharges'] = pd.to_numeric(contract['TotalCharges'], errors='coerce')
contract.loc[contract['TotalCharges'].isnull(), 'TotalCharges'] = contract['MonthlyCharges']
contract['BeginDate'] = pd.to_datetime(contract['BeginDate'])
contract['EndDate'] = contract['EndDate'].replace(['No'], ['2020-02-01'])
contract['gone_client'] = contract['EndDate'].apply(lambda x: 0 if x=='2020-02-01' else 1)
contract['EndDate'] = pd.to_datetime(contract['EndDate'])

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# Верные решения по заменам)
#
# </div>

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   datetime64[ns]
#  2   EndDate           7043 non-null   datetime64[ns]
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   float64
#  8   gone_client       7043 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 495.3+ KB

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=contract, x='Type')
plt.show()

# %% [markdown]
# - В датафрейме contract содержится информация о договорах клиентов.
# - Всего в датафрейме 7043 записи о клиентах, каждая из которых имеет 8 столбцов с различными характеристиками.
# - Столбец "customerID" является уникальным идентификатором клиента.
# - Основные признаки включают тип договора (ежемесячный, годовой и т.д.), способ оплаты, ежемесячные траты на услуги, всего потрачено денег на услуги и т.д.
# - Большинство пользователей предпочитают месячные договоры.

# %%
information(personal)
# Out:
# ----------------------------------------------------------------------------------------------------
# dataframe:
# ----------------------------------------------------------------------------------------------------
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes
# ----------------------------------------------------------------------------------------------------
# info:
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=personal, x='gender')
plt.show()

# %% [markdown]
# - В датафрейме personal содержатся персональные данные клиентов.
# - Данные включают информацию о поле, возрасте, партнер и иждивенцев.
# - Всего в датафрейме 7043 записи и 5 столбцов с данными.
# - Клиентов женщин и мужчин примерно равное количество.

# %%
information(internet)
# Out:
# ----------------------------------------------------------------------------------------------------
# dataframe:
# ----------------------------------------------------------------------------------------------------
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
# 5  9305-CDSKC     Fiber optic             No           No              Yes
# 6  1452-KIOVK     Fiber optic             No          Yes               No
# 7  6713-OKOMC             DSL            Yes           No               No
# 8  7892-POOKP     Fiber optic             No           No              Yes
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=internet, x='InternetService')
plt.show()

# %% [markdown]
# - В датафрейме internet содержится информация об интернет-услугах, которые используют клиенты.
# - Данные включают тип подключения (через DSL или оптоволоконный кабель), наличие стриминговых сервисов и т.д.
# - Всего в датафрейме 5517 записей и 8 столбцов с данными.

# %%
information(phone)
# Out:
# ----------------------------------------------------------------------------------------------------
# dataframe:
# ----------------------------------------------------------------------------------------------------
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# 5  7892-POOKP           Yes
# 6  6388-TABGU            No
# 7  9763-GRSKD            No
# 8  7469-LKBCI            No
# 9  8091-TTVAX           Yes
# ----------------------------------------------------------------------------------------------------
# info:
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=phone, x='MultipleLines')
plt.show()

# %% [markdown]
# - В датафрейме phone содержится информация об услугах телефона, которые используют клиенты.
# - Данные включают наличия возможности ведения параллельных линий во время звонка.
# - Всего в датафрейме 6361 запись и 2 столбца с данными.
# - Большинство пользователей не подключают услугу MultipleLines

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# Все данные на последней базе нашего курса и предварительно изучены, отлично!)
#
# </div>

# %% [markdown]
# ### Объединение данных и заполнение пропусков

# %%
data_list = [personal, internet, phone]
df = contract

for data in data_list:
    df = df.merge(data, how='left', on='customerID')
    
df = df.fillna('No')

# %%
information(df)
# Out:
# ----------------------------------------------------------------------------------------------------
# dataframe:
# ----------------------------------------------------------------------------------------------------
#    customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG 2020-01-01 2020-02-01  Month-to-month              Yes
# 1  5575-GNVDE 2017-04-01 2020-02-01        One year               No
# 2  3668-QPYBK 2019-10-01 2020-02-01  Month-to-month              Yes
# 3  7795-CFOCW 2016-05-01 2020-02-01        One year               No
# 4  9237-HQITU 2019-09-01 2020-02-01  Month-to-month              Yes
# 5  9305-CDSKC 2019-03-01 2020-02-01  Month-to-month              Yes
# 6  1452-KIOVK 2018-04-01 2020-02-01  Month-to-month              Yes
# 7  6713-OKOMC 2019-04-01 2020-02-01  Month-to-month               No
# 8  7892-POOKP 2017-07-01 2020-02-01  Month-to-month              Yes
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Успех ✔️</b>
#
# Объединение и заполнение пропусков сделаны корректно!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Итоговый комментарий тимлида ✔️</b>
#
# Принимаю работу по первой части, хорошо получилось) Можешь приступать ко второму этапу проекта!
#
# </div>

# %%
df.set_index('customerID', inplace=True)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2 ✔️</b>
#
# Комментарии ко второй части будут с таким заголовком
#
# </div>

# %% [markdown]
# ### Круговая диаграмма доли ушедших и оставшихся клиентов

# %%
gone_client_distribution = df['gone_client'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(gone_client_distribution, labels=['Не ушел', 'Ушел'], autopct='%1.1f%%', startangle=90)
plt.title('Круговая диаграмма доли ушедших и оставшихся клиентов')
plt.show()

# %% [markdown]
# По данной круговой диаграмме можно сделать следующие выводы:
#
# - Ушедшие клиенты составляют примерно 16% от общего числа клиентов.
# - Оставшиеся клиенты составляют примерно 84% от общего числа клиентов.
#
# Доля оставшихся клиентов значительно превышает долю ушедших клиентов.

# %% [markdown]
# ### Гистограмма распределения признака "MonthlyCharges"

# %%
plt.figure(figsize=(10, 8))
sns.histplot(df['MonthlyCharges'], kde=True)
plt.title('Гистограмма распределения признака "MonthlyCharges"')
plt.xlabel('Monthly Charges')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Monthly Charges - ежемесячные траты клиента на услуги
#
# Из данного графика можно сделать следующие выводы:
#
# - Большинство клиентов имеют ежемесячные траты на услуги в диапазоне от 20 до 100. Это говорит о том, что большинство клиентов выбирают более доступные тарифные планы или услуги.
#
# - Наблюдается пик у значения 20, что может указывать на наличие более дешевого базового тарифного плана.
#
# - Некоторое количество клиентов имеют ежемесячные траты свыше 100, что может быть связано с выбором дорогих тарифных планов или использованием дополнительных услуг.
#
# - Распределение расходов клиентов на услуги имеет правостороннюю форму, что означает наличие небольшого количества клиентов с очень высокими ежемесячными расходами.
#
# В целом, гистограмма распределения признака "MonthlyCharges" позволяет нам увидеть общую структуру расходов клиентов на услуги и делать предположения о предпочтениях клиентов и возможных тарифных планах, которые предлагаются.

# %% [markdown]
# ### Гистограмма распределения признака "TotalCharges"

# %%
plt.figure(figsize=(10, 8))
sns.histplot(df['TotalCharges'], kde=True)
plt.title('Гистограмма распределения признака "TotalCharges"')
plt.xlabel('Total Charges')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Total Charges - всего потрачено денег на услуги
#
# Из данного графика можно сделать следующие выводы:
#
# - Большинство клиентов потратили относительно небольшую сумму денег на услуги. Верхняя часть гистограммы, которая представляет клиентов с низкими расходами, является значительно более широкой и имеет наибольшую плотность. Это указывает на то, что большинство клиентов относительно экономично используют услуги.
#
# - Есть небольшое количество клиентов, которые значительно превышают средние расходы на услуги. Это отображается пиками на гистограмме в более высоких значениях. Это может указывать на то, что у некоторых клиентов есть более высокая потребность в услугах или они используют более дорогие планы.
#
# - Гистограмма имеет правостороннее смещение, что означает, что есть небольшая группа клиентов, которые готовы вкладывать больше денег за услуги. Это может быть связано с использованием дополнительных услуг или перерасходом плана.
#
# Гистограмма распределения признака "TotalCharges" позволяет представить распределение расходов клиентов на услуги и выявить основные тренды в потреблении услуг данной компании.

# %% [markdown]
# ### Анализ распределений

# %%
for val in [
    'Type',
    'PaperlessBilling',
    'PaymentMethod',
    'gender',
    'Partner',
    'Dependents',
    'InternetService',
    'OnlineSecurity',
    'OnlineBackup',
    'DeviceProtection',
    'TechSupport',
    'StreamingTV',
    'StreamingMovies',
    'MultipleLines'
]:
    df.pivot_table(
        index=val, values='gone_client', aggfunc='mean'
    ).plot(
        kind='bar', figsize=(10, 6)
    )
    
    plt.title(val, fontsize=18)
    plt.legend(fontsize=12)
    plt.xlabel('Значения', fontsize=15)
    plt.ylabel('Доля', fontsize=15)
    plt.grid(True, axis='y')
    plt.show()
    
    print('-' * 100)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# При анализе распределений можно отметить следующие результаты:
#
# - Пользователи, подключившие опцию MultipleLines, имеют большую вероятность ухода, чем те, кто не подключал данную опцию.
# - Использование автоматических платежей также сопряжено с частым уходом клиентов.
# - Аналогичная тенденция наблюдается и для других дополнительных интернет-опций (OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies).
# - Клиенты, заключавшие контракты на 1 или 2 года, также больше склонны к уходу, чем те, кто выбирает ежемесячную оплату.
#
# Клиент, склонный к уходу, обычно является семейным человеком с иждивенцами, который платит высокую ежемесячную сумму. При этом, размер платежа обусловлен подключением множества дополнительных опций

# %% [markdown]
# ### Корреляционная матрица

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(df.phik_matrix(), vmin=-1, vmax=1, center= 0, annot=True, cmap=sns.cubehelix_palette(as_cmap=True), fmt='.1g')
plt.title('Корреляционная матрица Phi_K для всех данных')
plt.show()
# Out:
# interval columns not set, guessing: ['MonthlyCharges', 'TotalCharges', 'gone_client', 'SeniorCitizen']

# %% [markdown]
# - избавимся от признака gender, т.к. данный признак не коррелирует с данными.
# - избавимся от признака TotalCharges, т.к. он копирует признаки MonthlyCharges.
# - заменим признаки EndDate и BeginDate на инервал времени.

# %% [markdown]
# ### Удаление столбцов

# %%
df['interval_date'] = (df['EndDate'] - df['BeginDate']).dt.days

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2 ✔️</b>
#
# Отличный новый признак, думаю он поможет нашим моделям
#
# </div>

# %%
drop_list = ['BeginDate', 'EndDate', 'TotalCharges', 'gender']

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].astype('object')

# %%
new_df = df.drop(columns=drop_list)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7043 non-null   object
#  1   PaperlessBilling  7043 non-null   object
#  2   PaymentMethod     7043 non-null   object
#  3   MonthlyCharges    7043 non-null   float64
#  4   gone_client       7043 non-null   int64
#  5   SeniorCitizen     7043 non-null   object
#  6   Partner           7043 non-null   object
#  7   Dependents        7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  MultipleLines     7043 non-null   object
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2 ✔️</b>
#
# Все верно, они нам будут только мешать
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Провели анализ данных.
# - Построили портрет клиента склонного к уходу - обычно является семейным человеком с иждивенцами, который платит высокую ежемесячную сумму. При этом, размер платежа обусловлен подключением множества дополнительных опций.
# - Удалили данные признаки ('BeginDate', 'EndDate', 'TotalCharges', 'gender')
# - Добавили признак 'interval_date'

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Подготовка

# %%
features = new_df.drop('gone_client', axis=1)
target = new_df['gone_client']

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=random_state)

# %%
ohe_features = features.select_dtypes('object').columns.to_list()
num_features = features.select_dtypes(exclude='object').columns.to_list()

# %%
print('ohe_features:')
display(ohe_features)

print('num_features:')
display(num_features)
# Out:
# ohe_features:
# ['Type',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'MultipleLines']
# num_features:
# ['MonthlyCharges', 'interval_date']

# %% [markdown]
# <div class="alert alert-block alert-danger"; style="border-left: 6px solid red">
# <b>Комментарий тимлида V2 ❌</b>
#
# У нас в список численных признаков попал SeniorCitizen, что в итоге приводит к тому, что ниже мы его масштабируем, а это конечно неверно) Он должен быть в другом списке признаков
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Там где удалял столбцы, добавил строчку с изменением типа df['SeniorCitizen'] = df['SeniorCitizen'].astype('object')

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2.2 ✔️</b>
#
# Отлично!
#
# </div>

# %% [markdown]
# ### LogisticRegression

# %%
# %%time

transformer_lr = make_column_transformer(
    (
        OneHotEncoder(handle_unknown='ignore'), 
        ohe_features
    ),
    (
        StandardScaler(), 
        num_features
    ),
    remainder='passthrough'
)

model_lr = LogisticRegression(random_state=random_state, class_weight='balanced')

pipeline_lr = make_pipeline(transformer_lr, model_lr)

param_grid_lr = {
    'logisticregression__solver': ['lbfgs'],
    'logisticregression__C': [0.1, 1, 10]
}

grid_lr = GridSearchCV(pipeline_lr, param_grid_lr, scoring='roc_auc', cv=5)

grid_lr.fit(features_train, target_train)

lr_best_auc_roc = grid_lr.best_score_

print('Лучшие параметры модели LogisticRegression: ', grid_lr.best_params_)
print(f'AUC-ROC модели LogisticRegression: {lr_best_auc_roc:.3f}')
# Out:
# Лучшие параметры модели LogisticRegression:  {'logisticregression__C': 1, 'logisticregression__solver': 'lbfgs'}
# AUC-ROC модели LogisticRegression: 0.763
# CPU times: total: 578 ms
# Wall time: 532 ms

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2 ✔️</b>
#
# ✅
#
# </div>

# %% [markdown]
# ### CatBoostClassifier

# %%
features_train_c = features_train.copy()
features_test_c = features_test.copy()

features_train_c[ohe_features] = features_train_c[ohe_features].astype('category')
features_test_c[ohe_features] = features_test_c[ohe_features].astype('category')

# %%
# %%time

model_cb = CatBoostClassifier(
    random_state=random_state, 
    auto_class_weights='Balanced',
    cat_features=ohe_features
)

param_grid_cb = {
    'max_depth': [4, 6, 8],
    'learning_rate': [0.01, 0.1, 1]
}

grid_cb =  GridSearchCV(
    model_cb, 
    param_grid=param_grid_cb, 
    scoring='roc_auc', 
    n_jobs=-1,
    verbose=3
)

grid_cb.fit(features_train_c, target_train)

cb_best_auc_roc = grid_cb.best_score_

print('Лучшие параметры модели CatBoostClassifier: ', grid_cb.best_params_)
print(f'AUC-ROC модели CatBoostClassifier: {cb_best_auc_roc:.3f}')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# 0:	learn: 0.6696795	total: 167ms	remaining: 2m 46s
# 1:	learn: 0.6471371	total: 180ms	remaining: 1m 29s
# 2:	learn: 0.6289512	total: 200ms	remaining: 1m 6s
# 3:	learn: 0.6122408	total: 215ms	remaining: 53.6s
# 4:	learn: 0.5998146	total: 238ms	remaining: 47.3s
# 5:	learn: 0.5879986	total: 253ms	remaining: 41.9s
# 6:	learn: 0.5775412	total: 303ms	remaining: 42.9s
# 7:	learn: 0.5679767	total: 331ms	remaining: 41.1s
# 8:	learn: 0.5605385	total: 356ms	remaining: 39.2s
# 9:	learn: 0.5552374	total: 378ms	remaining: 37.5s
# 10:	learn: 0.5522028	total: 410ms	remaining: 36.8s
# 11:	learn: 0.5456773	total: 424ms	remaining: 34.9s
# 12:	learn: 0.5420640	total: 437ms	remaining: 33.2s
# 13:	learn: 0.5369519	total: 452ms	remaining: 31.8s
# 14:	learn: 0.5342811	total: 465ms	remaining: 30.5s
# 15:	learn: 0.5303981	total: 506ms	remaining: 31.1s
# 16:	learn: 0.5262255	total: 520ms	remaining: 30s
# ...

# %% [markdown]
# ### LGBMClassifier

# %%
# %%time

model_lgbm = LGBMClassifier(random_state=random_state)

param_grid_lgbm = {
    'lgbmclassifier__boosting_type': ['gbdt'],
    'lgbmclassifier__num_leaves': [10, 20, 30],
    'lgbmclassifier__learning_rate': [0.1, 0.3, 0.5],
    'lgbmclassifier__n_estimators': [50, 100, 200]
}

grid_lgbm = GridSearchCV(
    model_lgbm, 
    param_grid_lgbm, 
    scoring='roc_auc', 
    cv=5
)

grid_lgbm.fit(features_train_c, target_train)

lgbm_best_auc_roc = grid_lgbm.best_score_

print('Лучшие параметры модели LGBMClassifier: ', grid_lgbm.best_params_)
print(f'AUC-ROC модели LGBMClassifier: {lgbm_best_auc_roc:.3f}')
# Out:
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__num_leaves
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__boosting_type
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__num_leaves
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__boosting_type
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__num_leaves
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__boosting_type
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__learning_rate
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__n_estimators
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__num_leaves
# [LightGBM] [Warning] Unknown parameter: lgbmclassifier__boosting_type
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"; style="border-left: 6px solid orange">
# <b>Комментарий тимлида V2 ⚠️</b>
#
# LGBM не требуется масштабирование и эта модель отлично работает на незакодированных выборках, для этого надо просто изменить тип данных на category у категориальных признаков. По сути пайплайн тут лишний)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# убрал все лишнее и поскольку я это делал в CatBoost'e, то просто взял от туда 'features_train_c'

# %% [markdown]
# ### Выбор лучшей модели

# %%
result = pd.DataFrame(
    [lgbm_best_auc_roc, lr_best_auc_roc, cb_best_auc_roc], 
    index=['LGBMClassifier', 'LogisticRegression', 'CatBoostCLassifier'], 
    columns=['AUC-ROC']
).sort_values(by=['AUC-ROC'])
result
# Out:
#                      AUC-ROC
# LogisticRegression  0.763283
# LGBMClassifier      0.877055
# CatBoostCLassifier  0.919718

# %% [markdown]
# Лучшая модель - CatBoostCLassifier с AUC-ROC = 0.92

# %%
best_model = grid_cb

# %% [markdown]
# ## Тестирование лучшей модели

# %% [markdown]
# ### Тестирование CatBoostCLassifier / ROC-кривая

# %%
# Получение вероятностей предсказания
pred_proba = best_model.predict_proba(features_test_c)[:, 1]

# Вычисление значения метрик AUC-ROC на тестовом наборе данных
test_auc_roc = roc_auc_score(target_test, pred_proba)
print(f'AUC-ROC лучшей модели на тестовой выборке: {test_auc_roc}')

# Вычисление значений False Positive Rate (FPR) и True Positive Rate (TPR)
fpr, tpr, thresholds = roc_curve(target_test, pred_proba)

# Построение ROC-кривой
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, label='ROC-кривая (AUC = %0.2f)' % test_auc_roc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUC-ROC лучшей модели на тестовой выборке: 0.9245782753392392

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2 ✔️</b>
#
# Проверка есть, порог прошли!
#
# </div>

# %% [markdown]
# Исходя из данной ROC-кривой, можно сделать следующие выводы:
#
# - Кривая находится высоко в левом верхнем углу графика, что указывает на хорошую производительность модели. Чем ближе кривая к верхнему левому углу, тем лучше модель отличает положительные и отрицательные случаи.
# - Значение AUC-ROC для данной модели также высоко, что свидетельствует о хорошей дискриминативной способности модели. Высокое значение AUC-ROC означает, что модель правильно предсказывает с высокой вероятностью.

# %% [markdown]
# ### Матрица ошибок

# %%
# Получение предсказанных меток
pred = best_model.predict(features_test_c)

# Вычисление матрицы ошибок
confusion_matrix = confusion_matrix(target_test, pred)

# Построение матрицы ошибок
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Матрица ошибок')
plt.xlabel('Предсказанные значения')
plt.ylabel('Реальные значения')
plt.show()

# %% [markdown]
# Исходя из данной матрицы ошибок, можно сделать следующие выводы:
#
# - Количество True Positive (верно предсказанных положительных значений) велико, что говорит о хорошей способности модели к правильному предсказанию положительных случаев.
# - Количество False Negative (ошибочно предсказанных отрицательных значений) низкое, что также свидетельствует о хорошей работе модели в предсказании положительных случаев.
# - Количество False Positive (ошибочно предсказанных положительных значений) также низкое, что говорит о хорошей способности модели к правильному предсказанию отрицательных случаев.
# - Количество True Negative (верно предсказанных отрицательных значений) высоко, указывая на хорошую способность модели к правильному предсказанию отрицательных случаев.
#
# Исходя из этой матрицы ошибок, можно заключить, что модель демонстрирует хорошую производительность и способность к правильному классифицированию в данном случае.

# %% [markdown]
# ### Исследование важности признаков

# %%
# Вычисление важности признаков
result = permutation_importance(best_model, features_test_c, target_test, n_repeats=10, random_state=random_state)
sorted_idx = result.importances_mean.argsort()

# Построение графика важности признаков
fig, ax = plt.subplots()
ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=features_test_c.columns[sorted_idx])
ax.set_title('Важность признаков')
plt.xlabel('Важность')
plt.ylabel('Признаки')
plt.show()

# %% [markdown]
# Наибольший вклад внесли следующие признаки:
# - interval_date
# - Type
# - MonthlyCharges
# - StreamingMovies

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Мы смогли добиться поставленной цели 0.85 <= AUC-ROC
# - Лучшая модель CatBoostCLassifier на тестовой выборке имеет AUC-ROC = 0.92

# %% [markdown]
# <div class="alert alert-block alert-warning"; style="border-left: 6px solid orange">
# <b>Итоговый комментарий тимлида V2 ⚠️</b>
#
# Очень хорошая и уверенная работа, моделирование, анализ, сам код, его аккуратность, все сделано на хорошем уровне, вижу, что есть понимание процессов, молодец! Я был готов принять уже вторую часть, но заметил момент с признаком не в том списке, давай поправим, чтобы к твоей работе вообще никаких вопросов не было) Буду ждать!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Отчеты на выходных вы проверяете сутки или дольше ?

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Комментарий тимлида V2.2 ✔️</b>
#
# Зависит от количества работ, которые мне отправят)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Итоговый комментарий тимлида V2.2 ✔️</b>
#
# Принимаю вторую часть, можешь приступать к финальному этапу - отчету)
#
# </div>

# %% [markdown]
# ## Отчет по проекту "Телекоммуникации"

# %% [markdown]
# ### Цель и план проекта

# %% [markdown]
# #### План:

# %% [markdown]
# 1. Изучение заданий и требований к данному проекту.
# 2. Подготовка данных.
# 3. Анализ данных.
# 4. Обучение моделей.
# 5. Тестирование лучшей модели.

# %% [markdown]
# Удалось выполнить все пункты плана к данному проекту.

# %% [markdown]
# #### Цель:

# %% [markdown]
# - При проверке качества лучшей модели на тестовой выборке надо получить 0.85 <= AUC-ROC

# %% [markdown]
# Выполняя данный проект удалось добиться поставленной цели (AUC-ROC = 0.92)

# %% [markdown]
# ### Трудности в выполненении проекта

# %% [markdown]
# - Из-за моей невнимательности в список численных признаков (num_features) попал SeniorCitizen, что в итоге привело к масштабируемости данного признака.
# - Данная ошибка повлияла на результаты и на длительность выполнения проекта.
# - Исправил этот момент - сменой типа у данного признака `df['SeniorCitizen'] = df['SeniorCitizen'].astype('object')`

# %% [markdown]
# ### Ключевые шаги проекта

# %% [markdown]
# 1. Подготовка:
#     1. Загрузка и просмотр данных:
#         1. Произвел предобработку данных в датафрейме `contract` и добавил признак `gone_client`, который показывает статус ухода клиента.
#         2. Объеденил данные `[contract, personal, internet, phone]` в единый датафрейм `df`.
#         3. Заполнил пропуски в едином датафрейме `df` на 'No'.
# 2. Анализ данных:
#     1. Доля оставшихся клиентов значительно превышает долю ушедших клиентов:
#         - Ушедшие клиенты составляют примерно 16% от общего числа клиентов.
#         - Оставшиеся клиенты составляют примерно 84% от общего числа клиентов.
#     2. Гистограмма распределения признака `MonthlyCharges`:
#         - Большинство клиентов имеют ежемесячные траты на услуги в диапазоне от 20 до 100. Это говорит о том, что большинство клиентов выбирают более доступные тарифные планы или услуги.
#         - Наблюдается пик у значения 20, что может указывать на наличие более дешевого базового тарифного плана.
#         - Некоторое количество клиентов имеют ежемесячные траты свыше 100, что может быть связано с выбором дорогих тарифных планов или использованием дополнительных услуг.
#         - Распределение расходов клиентов на услуги имеет правостороннюю форму, что означает наличие небольшого количества клиентов с очень высокими ежемесячными расходами.
#     3. Гистограмма распределения признака `TotalCharges`:
#         - Большинство клиентов потратили относительно небольшую сумму денег на услуги. Верхняя часть гистограммы, которая представляет клиентов с низкими расходами, является значительно более широкой и имеет наибольшую плотность. Это указывает на то, что большинство клиентов относительно экономично используют услуги.
#         - Есть небольшое количество клиентов, которые значительно превышают средние расходы на услуги. Это отображается пиками на гистограмме в более высоких значениях. Это может указывать на то, что у некоторых клиентов есть более высокая потребность в услугах или они используют более дорогие планы.
#         - Гистограмма имеет правостороннее смещение, что означает, что есть небольшая группа клиентов, которые готовы вкладывать больше денег за услуги. Это может быть связано с использованием дополнительных услуг или перерасходом плана.
#     4. Анализ распределений:
#         - Построили портрет клиента склонного к уходу - обычно является семейным человеком с иждивенцами, который платит высокую ежемесячную сумму. При этом, размер платежа обусловлен подключением множества дополнительных опций.
#     5. Корреляционная матрица:
#         - Избавились от признака gender, т.к. данный признак не коррелирует с данными.
#         - Избавились от признака TotalCharges, т.к. он копирует признаки MonthlyCharges.
#         - Заменили признаки EndDate и BeginDate на инервал времени.
# 3. Обучение моделей:
#     1. Подготовили данные к обучению.
#     2. Наборы признаков для обучения:
#         1. Численные:
#             - MonthlyCharges
#             - interval_date
#         2. Категориальные:
#             - Type
#             - PaperlessBilling
#             - PaymentMethod
#             - SeniorCitizen
#             - Partner
#             - Dependents
#             - InternetService
#             - OnlineSecurity
#             - OnlineBackup
#             - DeviceProtection
#             - TechSupport
#             - StreamingTV
#             - StreamingMovies
#             - MultipleLines
#     3. Модели:
#         1. LogisticRegression:
#             - StandardScaler стандартизировал численные признаки.
#             - OneHotEncoder закодировал категориальные признаки.
#             - GridSearchCV подбирал гиперпараметры.
#             - Лучшие параметры - `{'logisticregression__C': 1, 'logisticregression__solver': 'lbfgs'}`
#             - AUC-ROC = 0.76
#         2. CatBoostClassifier:
#             - Категориальным признакам поменяли тип данных с `object` на `category`.
#             - GridSearchCV подбирал гиперпараметры.
#             - Лучшие параметры - `{'learning_rate': 0.1, 'max_depth': 4}`
#             - AUC-ROC = 0.92
#         3. LGBMClassifier:
#             - Категориальным признакам поменяли тип данных с `object` на `category`.
#             - GridSearchCV подбирал гиперпараметры.
#             - Лучшие параметры - `{'lgbmclassifier__boosting_type': 'gbdt', 'lgbmclassifier__learning_rate': 0.1, 'lgbmclassifier__n_estimators': 50, 'lgbmclassifier__num_leaves': 10}`
#             - AUC-ROC = 0.87
#     4. Выбор лучшей модели:
#         - Лучшая модель - CatBoostCLassifier
#         - AUC-ROC = 0.92
#         - Параметры - `{'lgbmclassifier__boosting_type': 'gbdt', 'lgbmclassifier__learning_rate': 0.1, 'lgbmclassifier__n_estimators': 50, 'lgbmclassifier__num_leaves': 10}`
# 4. Тестирование лучшей модели:
#     1. Тестирование CatBoostCLassifier:
#         - AUC-ROC лучшей модели на тестовой выборке (25% от исходного датасета): `0.92`
#     2. ROC-кривая:
#         - Кривая находится высоко в левом верхнем углу графика, что указывает на хорошую производительность модели. Чем ближе кривая к верхнему левому углу, тем лучше модель отличает положительные и отрицательные случаи.
#         - Значение AUC-ROC для данной модели также высоко, что свидетельствует о хорошей дискриминативной способности модели. Высокое значение AUC-ROC означает, что модель правильно предсказывает с высокой вероятностью.
#     3. Матрица ошибок:
#         - Количество True Positive (верно предсказанных положительных значений) велико, что говорит о хорошей способности модели к правильному предсказанию положительных случаев.
#         - Количество False Negative (ошибочно предсказанных отрицательных значений) низкое, что также свидетельствует о хорошей работе модели в предсказании положительных случаев.
#         - Количество False Positive (ошибочно предсказанных положительных значений) также низкое, что говорит о хорошей способности модели к правильному предсказанию отрицательных случаев.
#         - Количество True Negative (верно предсказанных отрицательных значений) высоко, указывая на хорошую способность модели к правильному предсказанию отрицательных случаев.
#     4. Исследование важности признаков (наибольший вклад внесли следующие признаки):
#         - interval_date
#         - Type
#         - MonthlyCharges
#         - StreamingMovies

# %% [markdown]
# <div class="alert alert-block alert-success"; style="border-left: 6px solid green">
# <b>Итоговый комментарий тимлида V3 ✔️</b>
#
# Спасибо за проделанную работу! Получился отличный отчет) Принимаю финальный проект и поздравляю с завершением курса! Впереди еще будет много интересного, сфера Data Science постоянно развивается и не дает скучать) Мы еще увидимся на финальном созвоне, а пока что можно чуть-чуть отдохнуть!
#
# ----
#
# ![image.png](attachment:image.png)
#
# </div>
